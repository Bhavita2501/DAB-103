# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavita2501/DAB-103/blob/PHASE_2_CLEANED_DATA/2.Ph_2_Cleaned_state_level_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_dir = 'drive/MyDrive/PYTHON-DEMO/# 0 PROJECT/'

# %%
state_data = pd.read_csv(project_dir+ 'state_level_daily.csv')

# %%
state_data
# Out:
#       Unnamed: 0       Date State  Confirmed  Deceased  Recovered  \
# 0              0  01-Apr-20    AN          0         0          0
# 1              1  01-Apr-20    AP         67         0          1
# 2              2  01-Apr-20    AR          0         0          0
# 3              3  01-Apr-20    AS         15         0          0
# 4              4  01-Apr-20    BR          3         0          0
# ...          ...        ...   ...        ...       ...        ...
# 5689        5689  31-May-20    TT       8789       222       4928
# 5690        5690  31-May-20    UN        448         0          0
# 5691        5691  31-May-20    UP        374         4        192
# 5692        5692  31-May-20    UT        158         0          0
# 5693        5693  31-May-20    WB        371         8        187
#
#                        State_Name
# 0     Andaman and Nicobar Islands
# 1                  Andhra Pradesh
# 2               Arunachal Pradesh
# ...

# %%
state_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5694 entries, 0 to 5693
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5694 non-null   int64
#  1   Date        5694 non-null   object
#  2   State       5694 non-null   object
#  3   Confirmed   5694 non-null   int64
#  4   Deceased    5694 non-null   int64
#  5   Recovered   5694 non-null   int64
#  6   State_Name  5694 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 311.5+ KB

# %% [markdown]
# # **_ "Unnamed: 0" column not needed**

# %%
state_data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
state_data
# Out:
#            Date State  Confirmed  Deceased  Recovered  \
# 0     01-Apr-20    AN          0         0          0
# 1     01-Apr-20    AP         67         0          1
# 2     01-Apr-20    AR          0         0          0
# 3     01-Apr-20    AS         15         0          0
# 4     01-Apr-20    BR          3         0          0
# ...         ...   ...        ...       ...        ...
# 5689  31-May-20    TT       8789       222       4928
# 5690  31-May-20    UN        448         0          0
# 5691  31-May-20    UP        374         4        192
# 5692  31-May-20    UT        158         0          0
# 5693  31-May-20    WB        371         8        187
#
#                        State_Name
# 0     Andaman and Nicobar Islands
# 1                  Andhra Pradesh
# 2               Arunachal Pradesh
# 3                           Assam
# 4                           Bihar
# ...                           ...
# 5689                        Total
# ...

# %% [markdown]
# # **setting columne 'State_Name' as index because its common in both data set "state_level_daily" and "patients_data" Dataset **

# %%
state_data.set_index('State_Name',inplace=True)

# %%
state_data
# Out:
#                                   Date State  Confirmed  Deceased  Recovered
# State_Name
# Andaman and Nicobar Islands  01-Apr-20    AN          0         0          0
# Andhra Pradesh               01-Apr-20    AP         67         0          1
# Arunachal Pradesh            01-Apr-20    AR          0         0          0
# Assam                        01-Apr-20    AS         15         0          0
# Bihar                        01-Apr-20    BR          3         0          0
# ...                                ...   ...        ...       ...        ...
# Total                        31-May-20    TT       8789       222       4928
# State Unassigned             31-May-20    UN        448         0          0
# Uttar Pradesh                31-May-20    UP        374         4        192
# Uttarakhand                  31-May-20    UT        158         0          0
# West Bengal                  31-May-20    WB        371         8        187
#
# [5694 rows x 5 columns]

# %% [markdown]
# # convert the 'date' column to datetime type
# df['date'] = pd.to_datetime(df['date'], format='%d-%b-%y')

# %%
# convert the 'date' column to datetime type

state_data['Date'] = pd.to_datetime(state_data['Date'], format='%d-%b-%y')

# %%
state_data
# Out:
#                                   Date State  Confirmed  Deceased  Recovered
# State_Name
# Andaman and Nicobar Islands 2020-04-01    AN          0         0          0
# Andhra Pradesh              2020-04-01    AP         67         0          1
# Arunachal Pradesh           2020-04-01    AR          0         0          0
# Assam                       2020-04-01    AS         15         0          0
# Bihar                       2020-04-01    BR          3         0          0
# ...                                ...   ...        ...       ...        ...
# Total                       2020-05-31    TT       8789       222       4928
# State Unassigned            2020-05-31    UN        448         0          0
# Uttar Pradesh               2020-05-31    UP        374         4        192
# Uttarakhand                 2020-05-31    UT        158         0          0
# West Bengal                 2020-05-31    WB        371         8        187
#
# [5694 rows x 5 columns]

# %%
state_data = state_data.sort_values(by='Date', key=lambda x: pd.to_datetime(x).dt.month)

# %%
state_data
# Out:
#                                   Date State  Confirmed  Deceased  Recovered
# State_Name
# Andaman and Nicobar Islands 2020-03-15    AN          0         0          0
# Ladakh                      2020-03-19    LA          0         0          0
# Lakshadweep                 2020-03-19    LD          0         0          0
# Maharashtra                 2020-03-19    MH          4         0          0
# Meghalaya                   2020-03-19    ML          0         0          0
# ...                                ...   ...        ...       ...        ...
# State Unassigned            2020-08-05    UN          0         0          0
# Total                       2020-08-05    TT      51387       804      39552
# Tripura                     2020-08-05    TR        122         2         50
# Himachal Pradesh            2020-08-04    HP         61         0         52
# Tripura                     2020-08-04    TR        131         1         70
#
# [5694 rows x 5 columns]

# %% [markdown]
# #**convert the 'date' column to the desired string format**

# %%
# convert the 'date' column to the desired string format
state_data['Date'] = state_data['Date'].dt.strftime('%d/%m/%Y')

# %%
state_data
# Out:
#                                    Date State  Confirmed  Deceased  Recovered
# State_Name
# Andaman and Nicobar Islands  15/03/2020    AN          0         0          0
# Ladakh                       19/03/2020    LA          0         0          0
# Lakshadweep                  19/03/2020    LD          0         0          0
# Maharashtra                  19/03/2020    MH          4         0          0
# Meghalaya                    19/03/2020    ML          0         0          0
# ...                                 ...   ...        ...       ...        ...
# State Unassigned             05/08/2020    UN          0         0          0
# Total                        05/08/2020    TT      51387       804      39552
# Tripura                      05/08/2020    TR        122         2         50
# Himachal Pradesh             04/08/2020    HP         61         0         52
# Tripura                      04/08/2020    TR        131         1         70
#
# ...

# %% [markdown]
# # **saving the cleaned data**

# %%
state_data.to_csv('drive/MyDrive/PYTHON-DEMO/# 0 PROJECT/2.Cleaned_StateData.csv', index=False)
