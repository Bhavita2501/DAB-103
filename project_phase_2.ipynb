# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavita2501/DAB-103/blob/main/project_phase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mounting drive**

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
project_dir = 'drive/MyDrive/PYTHON-DEMO/# 0 PROJECT/'

# %%
pat_data = pd.read_csv(project_dir+ 'patients_data.csv')
# Out:
# <ipython-input-105-90e67535fd2b>:1: DtypeWarning: Columns (4,12,13,14,15,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   pat_data = pd.read_csv(project_dir+ 'patients_data.csv')

# %%
pat_data
# Out:
#         Patient Number State Patient Number Date Announced  \
# 0                  1.0             KL-TS-P1     30/01/2020
# 1                  2.0             KL-AL-P1     02/02/2020
# 2                  3.0             KL-KS-P1     03/02/2020
# 3                  4.0                DL-P1     02/03/2020
# 4                  5.0                TS-P1     02/03/2020
# ...                ...                  ...            ...
# 247231             NaN                  NaN     06/08/2020
# 247232             NaN                  NaN     06/08/2020
# 247233             NaN                  NaN     06/08/2020
# 247234             NaN                  NaN     06/08/2020
# 247235             NaN                  NaN            NaN
#
#         Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                        NaN          20      F                  Thrissur
# 1                        NaN         NaN    NaN                 Alappuzha
# 2                        NaN         NaN    NaN                 Kasaragod
# 3                        NaN          45      M  East Delhi (Mayur Vihar)
# 4                        NaN          24      M                 Hyderabad
# ...                      ...         ...    ...                       ...
# 247231                   NaN         NaN    NaN                       NaN
# 247232                   NaN         NaN    NaN                       NaN
# 247233                   NaN         NaN    NaN                       NaN
# 247234                   NaN         NaN    NaN                       NaN
# 247235                   NaN         NaN    NaN                       NaN
#
#        Detected District Detected State State code  ...  \
# 0               Thrissur         Kerala         KL  ...
# 1              Alappuzha         Kerala         KL  ...
# 2              Kasaragod         Kerala         KL  ...
# 3             East Delhi          Delhi         DL  ...
# 4              Hyderabad      Telangana         TG  ...
# ...                  ...            ...        ...  ...
# 247231               NaN            NaN        NaN  ...
# 247232               NaN            NaN        NaN  ...
# 247233               NaN            NaN        NaN  ...
# 247234               NaN            NaN        NaN  ...
# 247235               NaN            NaN        NaN  ...
#
#        Contracted from which Patient (Suspected) Nationality  \
# 0                                            NaN       India
# 1                                            NaN       India
# 2                                            NaN       India
# 3                                            NaN       India
# 4                                            NaN       India
# ...                                          ...         ...
# 247231                                       NaN         NaN
# 247232                                       NaN         NaN
# 247233                                       NaN         NaN
# 247234                                       NaN         NaN
# 247235                                       NaN         NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 247231                  NaN                NaN
# 247232                  NaN                NaN
# 247233                  NaN                NaN
# 247234                  NaN                NaN
# 247235                  NaN                NaN
#
#                                                  Source_1  \
# 0       https://twitter.com/vijayanpinarayi/status/122...
# 1       https://www.indiatoday.in/india/story/kerala-r...
# 2       https://www.indiatoday.in/india/story/kerala-n...
# 3       https://www.indiatoday.in/india/story/not-a-ja...
# 4       https://www.deccanherald.com/national/south/qu...
# ...                                                   ...
# 247231                                                NaN
# 247232                                                NaN
# 247233                                                NaN
# 247234                                                NaN
# 247235                                                NaN
#
#                                                  Source_2  \
# 0       https://weather.com/en-IN/india/news/news/2020...
# 1       https://weather.com/en-IN/india/news/news/2020...
# 2       https://twitter.com/ANI/status/122422148580539...
# 3       https://economictimes.indiatimes.com/news/poli...
# 4       https://www.indiatoday.in/india/story/coronavi...
# ...                                                   ...
# 247231                                                NaN
# 247232                                                NaN
# 247233                                                NaN
# 247234                                                NaN
# 247235                                                NaN
#
#                                                  Source_3  \
# 0                                                     NaN
# 1                                                     NaN
# 2       https://weather.com/en-IN/india/news/news/2020...
# 3                                                     NaN
# 4       https://www.thehindu.com/news/national/coronav...
# ...                                                   ...
# 247231                                                NaN
# 247232                                                NaN
# 247233                                                NaN
# 247234                                                NaN
# 247235                                                NaN
#
#                                       Backup Notes Num Cases  Entry_ID
# 0                               Student from Wuhan       1.0       NaN
# 1                               Student from Wuhan       1.0       NaN
# 2                               Student from Wuhan       1.0       NaN
# 3              Travel history to Italy and Austria       1.0       NaN
# 4       Travel history to Dubai, Singapore contact       1.0       NaN
# ...                                            ...       ...       ...
# 247231                                         NaN       NaN  218995.0
# 247232                                         NaN       NaN  218996.0
# 247233                                         NaN       NaN  218997.0
# 247234                                         NaN       NaN  218998.0
# 247235                                         NaN       NaN  218999.0
#
# [247236 rows x 22 columns]

# %%
pat_data.head(5)
# Out:
#    Patient Number State Patient Number Date Announced  Estimated Onset Date  \
# 0             1.0             KL-TS-P1     30/01/2020                   NaN
# 1             2.0             KL-AL-P1     02/02/2020                   NaN
# 2             3.0             KL-KS-P1     03/02/2020                   NaN
# 3             4.0                DL-P1     02/03/2020                   NaN
# 4             5.0                TS-P1     02/03/2020                   NaN
#
#   Age Bracket Gender             Detected City Detected District  \
# 0          20      F                  Thrissur          Thrissur
# 1         NaN    NaN                 Alappuzha         Alappuzha
# 2         NaN    NaN                 Kasaragod         Kasaragod
# 3          45      M  East Delhi (Mayur Vihar)        East Delhi
# 4          24      M                 Hyderabad         Hyderabad
#
#   Detected State State code  ... Contracted from which Patient (Suspected)  \
# 0         Kerala         KL  ...                                       NaN
# 1         Kerala         KL  ...                                       NaN
# 2         Kerala         KL  ...                                       NaN
# 3          Delhi         DL  ...                                       NaN
# 4      Telangana         TG  ...                                       NaN
#
#   Nationality Type of transmission Status Change Date  \
# 0       India             Imported         14/02/2020
# 1       India             Imported         14/02/2020
# 2       India             Imported         14/02/2020
# 3       India             Imported         15/03/2020
# 4       India             Imported         02/03/2020
#
#                                             Source_1  \
# 0  https://twitter.com/vijayanpinarayi/status/122...
# 1  https://www.indiatoday.in/india/story/kerala-r...
# 2  https://www.indiatoday.in/india/story/kerala-n...
# 3  https://www.indiatoday.in/india/story/not-a-ja...
# 4  https://www.deccanherald.com/national/south/qu...
#
#                                             Source_2  \
# 0  https://weather.com/en-IN/india/news/news/2020...
# 1  https://weather.com/en-IN/india/news/news/2020...
# 2  https://twitter.com/ANI/status/122422148580539...
# 3  https://economictimes.indiatimes.com/news/poli...
# 4  https://www.indiatoday.in/india/story/coronavi...
#
#                                             Source_3  \
# 0                                                NaN
# 1                                                NaN
# 2  https://weather.com/en-IN/india/news/news/2020...
# 3                                                NaN
# 4  https://www.thehindu.com/news/national/coronav...
#
#                                  Backup Notes Num Cases Entry_ID
# 0                          Student from Wuhan       1.0      NaN
# 1                          Student from Wuhan       1.0      NaN
# 2                          Student from Wuhan       1.0      NaN
# 3         Travel history to Italy and Austria       1.0      NaN
# 4  Travel history to Dubai, Singapore contact       1.0      NaN
#
# [5 rows x 22 columns]

# %%
pat_data.tail(5)
# Out:
#         Patient Number State Patient Number Date Announced  \
# 247231             NaN                  NaN     06/08/2020
# 247232             NaN                  NaN     06/08/2020
# 247233             NaN                  NaN     06/08/2020
# 247234             NaN                  NaN     06/08/2020
# 247235             NaN                  NaN            NaN
#
#         Estimated Onset Date Age Bracket Gender Detected City  \
# 247231                   NaN         NaN    NaN           NaN
# 247232                   NaN         NaN    NaN           NaN
# 247233                   NaN         NaN    NaN           NaN
# 247234                   NaN         NaN    NaN           NaN
# 247235                   NaN         NaN    NaN           NaN
#
#        Detected District Detected State State code  ...  \
# 247231               NaN            NaN        NaN  ...
# 247232               NaN            NaN        NaN  ...
# 247233               NaN            NaN        NaN  ...
# 247234               NaN            NaN        NaN  ...
# 247235               NaN            NaN        NaN  ...
#
#        Contracted from which Patient (Suspected) Nationality  \
# 247231                                       NaN         NaN
# 247232                                       NaN         NaN
# 247233                                       NaN         NaN
# 247234                                       NaN         NaN
# 247235                                       NaN         NaN
#
#        Type of transmission Status Change Date Source_1 Source_2 Source_3  \
# 247231                  NaN                NaN      NaN      NaN      NaN
# 247232                  NaN                NaN      NaN      NaN      NaN
# 247233                  NaN                NaN      NaN      NaN      NaN
# 247234                  NaN                NaN      NaN      NaN      NaN
# 247235                  NaN                NaN      NaN      NaN      NaN
#
#        Backup Notes Num Cases  Entry_ID
# 247231          NaN       NaN  218995.0
# 247232          NaN       NaN  218996.0
# 247233          NaN       NaN  218997.0
# 247234          NaN       NaN  218998.0
# 247235          NaN       NaN  218999.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # **Data Cleaning part 1**
# #### removing  rows with patient number ="NA"

# %%
pat_data['Patient Number'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 247231     True
# 247232     True
# 247233     True
# 247234     True
# 247235     True
# Name: Patient Number, Length: 247236, dtype: bool

# %%
pat_data['Patient Number'].isna().sum()
# Out:
# 147443

# %%
pat_data['Patient Number'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 247236 entries, 0 to 247235
# Series name: Patient Number
# Non-Null Count  Dtype
# --------------  -----
# 99793 non-null  float64
# dtypes: float64(1)
# memory usage: 1.9 MB

# %%
pat_data['Patient Number']
# Out:
# 0         1.0
# 1         2.0
# 2         3.0
# 3         4.0
# 4         5.0
#          ...
# 247231    NaN
# 247232    NaN
# 247233    NaN
# 247234    NaN
# 247235    NaN
# Name: Patient Number, Length: 247236, dtype: float64

# %% [markdown]
# # **Find null cells in column 'Patient Number'**

# %%
from zmq.constants import NULL
# Find rows with missing values
pat_null=pat_data['Patient Number'].isna()

# %%
pat_null
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 247231     True
# 247232     True
# 247233     True
# 247234     True
# 247235     True
# Name: Patient Number, Length: 247236, dtype: bool

# %% [markdown]
# # **removing patient Number which is NA**

# %%
pat_data.dropna(subset='Patient Number',inplace=True)

# %% [markdown]
# **1st cleaning**
#
# removing rows whose patient number = NA

# %%
pat_data #
# Out:
#         Patient Number State Patient Number Date Announced  \
# 0                  1.0             KL-TS-P1     30/01/2020
# 1                  2.0             KL-AL-P1     02/02/2020
# 2                  3.0             KL-KS-P1     03/02/2020
# 3                  4.0                DL-P1     02/03/2020
# 4                  5.0                TS-P1     02/03/2020
# ...                ...                  ...            ...
# 100279        102515.0                  NaN     19/06/2020
# 100280        102516.0                  NaN     19/06/2020
# 100281        102517.0                  NaN     19/06/2020
# 100282        102609.0                  NaN     19/06/2020
# 100283        102610.0                  NaN     19/06/2020
#
#         Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                        NaN          20      F                  Thrissur
# 1                        NaN         NaN    NaN                 Alappuzha
# 2                        NaN         NaN    NaN                 Kasaragod
# 3                        NaN          45      M  East Delhi (Mayur Vihar)
# 4                        NaN          24      M                 Hyderabad
# ...                      ...         ...    ...                       ...
# 100279                   NaN         NaN    NaN                       NaN
# 100280                   NaN         NaN    NaN                       NaN
# 100281                   NaN         NaN    NaN                       NaN
# 100282                   NaN         NaN    NaN                       NaN
# 100283                   NaN         NaN    NaN                       NaN
#
#        Detected District     Detected State State code  ...  \
# 0               Thrissur             Kerala         KL  ...
# 1              Alappuzha             Kerala         KL  ...
# 2              Kasaragod             Kerala         KL  ...
# 3             East Delhi              Delhi         DL  ...
# 4              Hyderabad          Telangana         TG  ...
# ...                  ...                ...        ...  ...
# 100279           Pulwama  Jammu and Kashmir         JK  ...
# 100280             Reasi  Jammu and Kashmir         JK  ...
# 100281          Kishtwar  Jammu and Kashmir         JK  ...
# 100282       East Sikkim             Sikkim         SK  ...
# 100283      South Sikkim             Sikkim         SK  ...
#
#        Contracted from which Patient (Suspected) Nationality  \
# 0                                            NaN       India
# 1                                            NaN       India
# 2                                            NaN       India
# 3                                            NaN       India
# 4                                            NaN       India
# ...                                          ...         ...
# 100279                                       NaN         NaN
# 100280                                       NaN         NaN
# 100281                                       NaN         NaN
# 100282                                       NaN         NaN
# 100283                                       NaN         NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 100279                  NaN                NaN
# 100280                  NaN                NaN
# 100281                  NaN                NaN
# 100282                  NaN                NaN
# 100283                  NaN                NaN
#
#                                                  Source_1  \
# 0       https://twitter.com/vijayanpinarayi/status/122...
# 1       https://www.indiatoday.in/india/story/kerala-r...
# 2       https://www.indiatoday.in/india/story/kerala-n...
# 3       https://www.indiatoday.in/india/story/not-a-ja...
# 4       https://www.deccanherald.com/national/south/qu...
# ...                                                   ...
# 100279  https://twitter.com/diprjk/status/127434387638...
# 100280  https://twitter.com/diprjk/status/127434387638...
# 100281  https://twitter.com/diprjk/status/127434387638...
# 100282  https://www.eastmojo.com/coronavirus-updates/2...
# 100283  https://www.eastmojo.com/coronavirus-updates/2...
#
#                                                  Source_2  \
# 0       https://weather.com/en-IN/india/news/news/2020...
# 1       https://weather.com/en-IN/india/news/news/2020...
# 2       https://twitter.com/ANI/status/122422148580539...
# 3       https://economictimes.indiatimes.com/news/poli...
# 4       https://www.indiatoday.in/india/story/coronavi...
# ...                                                   ...
# 100279                                                NaN
# 100280                                                NaN
# 100281                                                NaN
# 100282                                                NaN
# 100283                                                NaN
#
#                                                  Source_3  \
# 0                                                     NaN
# 1                                                     NaN
# 2       https://weather.com/en-IN/india/news/news/2020...
# 3                                                     NaN
# 4       https://www.thehindu.com/news/national/coronav...
# ...                                                   ...
# 100279                                                NaN
# 100280                                                NaN
# 100281                                                NaN
# 100282                                                NaN
# 100283                                                NaN
#
#                                       Backup Notes Num Cases Entry_ID
# 0                               Student from Wuhan       1.0      NaN
# 1                               Student from Wuhan       1.0      NaN
# 2                               Student from Wuhan       1.0      NaN
# 3              Travel history to Italy and Austria       1.0      NaN
# 4       Travel history to Dubai, Singapore contact       1.0      NaN
# ...                                            ...       ...      ...
# 100279                                         NaN       1.0  73145.0
# 100280                                         NaN       2.0  73146.0
# 100281                                         NaN      -2.0  73147.0
# 100282                                         NaN      -3.0  73239.0
# 100283                                         NaN       3.0  73240.0
#
# [99793 rows x 22 columns]

# %%
pat_data['Estimated Onset Date'].info() # All data of column Estimated Onset Date is NA so we delete "Estimated Onset Date" column
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 99793 entries, 0 to 100283
# Series name: Estimated Onset Date
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      float64
# dtypes: float64(1)
# memory usage: 1.5 MB

# %%
pat_data['Contracted from which Patient (Suspected)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 99793 entries, 0 to 100283
# Series name: Contracted from which Patient (Suspected)
# Non-Null Count  Dtype
# --------------  -----
# 1923 non-null   object
# dtypes: object(1)
# memory usage: 1.5+ MB

# %%
(1923*100)/99797
# Out:
# 1.9269116306101386

# %% [markdown]
# # **since 99 % of the cells in Contracted from which Patient (Suspected) column are null**
#
# # therefore we can delete this column

# %%
pat_data.drop('Contracted from which Patient (Suspected)',axis=1,inplace=True)

# %%
pat_data
# Out:
#         Patient Number State Patient Number Date Announced  \
# 0                  1.0             KL-TS-P1     30/01/2020
# 1                  2.0             KL-AL-P1     02/02/2020
# 2                  3.0             KL-KS-P1     03/02/2020
# 3                  4.0                DL-P1     02/03/2020
# 4                  5.0                TS-P1     02/03/2020
# ...                ...                  ...            ...
# 100279        102515.0                  NaN     19/06/2020
# 100280        102516.0                  NaN     19/06/2020
# 100281        102517.0                  NaN     19/06/2020
# 100282        102609.0                  NaN     19/06/2020
# 100283        102610.0                  NaN     19/06/2020
#
#         Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                        NaN          20      F                  Thrissur
# 1                        NaN         NaN    NaN                 Alappuzha
# 2                        NaN         NaN    NaN                 Kasaragod
# 3                        NaN          45      M  East Delhi (Mayur Vihar)
# 4                        NaN          24      M                 Hyderabad
# ...                      ...         ...    ...                       ...
# 100279                   NaN         NaN    NaN                       NaN
# 100280                   NaN         NaN    NaN                       NaN
# 100281                   NaN         NaN    NaN                       NaN
# 100282                   NaN         NaN    NaN                       NaN
# 100283                   NaN         NaN    NaN                       NaN
#
#        Detected District     Detected State State code  ...  \
# 0               Thrissur             Kerala         KL  ...
# 1              Alappuzha             Kerala         KL  ...
# 2              Kasaragod             Kerala         KL  ...
# 3             East Delhi              Delhi         DL  ...
# 4              Hyderabad          Telangana         TG  ...
# ...                  ...                ...        ...  ...
# 100279           Pulwama  Jammu and Kashmir         JK  ...
# 100280             Reasi  Jammu and Kashmir         JK  ...
# 100281          Kishtwar  Jammu and Kashmir         JK  ...
# 100282       East Sikkim             Sikkim         SK  ...
# 100283      South Sikkim             Sikkim         SK  ...
#
#                                                     Notes Nationality  \
# 0                                    Travelled from Wuhan       India
# 1                                    Travelled from Wuhan       India
# 2                                    Travelled from Wuhan       India
# 3                           Travelled from Austria, Italy       India
# 4       Travelled from Dubai to Bangalore on 20th Feb,...       India
# ...                                                   ...         ...
# 100279                                                NaN         NaN
# 100280                                                NaN         NaN
# 100281                                                NaN         NaN
# 100282     Entry was done on 13 Jun but re-concilled now          NaN
# 100283     Entry was done on 13 Jun but re-concilled now          NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 100279                  NaN                NaN
# 100280                  NaN                NaN
# 100281                  NaN                NaN
# 100282                  NaN                NaN
# 100283                  NaN                NaN
#
#                                                  Source_1  \
# 0       https://twitter.com/vijayanpinarayi/status/122...
# 1       https://www.indiatoday.in/india/story/kerala-r...
# 2       https://www.indiatoday.in/india/story/kerala-n...
# 3       https://www.indiatoday.in/india/story/not-a-ja...
# 4       https://www.deccanherald.com/national/south/qu...
# ...                                                   ...
# 100279  https://twitter.com/diprjk/status/127434387638...
# 100280  https://twitter.com/diprjk/status/127434387638...
# 100281  https://twitter.com/diprjk/status/127434387638...
# 100282  https://www.eastmojo.com/coronavirus-updates/2...
# 100283  https://www.eastmojo.com/coronavirus-updates/2...
#
#                                                  Source_2  \
# 0       https://weather.com/en-IN/india/news/news/2020...
# 1       https://weather.com/en-IN/india/news/news/2020...
# 2       https://twitter.com/ANI/status/122422148580539...
# 3       https://economictimes.indiatimes.com/news/poli...
# 4       https://www.indiatoday.in/india/story/coronavi...
# ...                                                   ...
# 100279                                                NaN
# 100280                                                NaN
# 100281                                                NaN
# 100282                                                NaN
# 100283                                                NaN
#
#                                                  Source_3  \
# 0                                                     NaN
# 1                                                     NaN
# 2       https://weather.com/en-IN/india/news/news/2020...
# 3                                                     NaN
# 4       https://www.thehindu.com/news/national/coronav...
# ...                                                   ...
# 100279                                                NaN
# 100280                                                NaN
# 100281                                                NaN
# 100282                                                NaN
# 100283                                                NaN
#
#                                       Backup Notes Num Cases  Entry_ID
# 0                               Student from Wuhan       1.0       NaN
# 1                               Student from Wuhan       1.0       NaN
# 2                               Student from Wuhan       1.0       NaN
# 3              Travel history to Italy and Austria       1.0       NaN
# 4       Travel history to Dubai, Singapore contact       1.0       NaN
# ...                                            ...       ...       ...
# 100279                                         NaN       1.0   73145.0
# 100280                                         NaN       2.0   73146.0
# 100281                                         NaN      -2.0   73147.0
# 100282                                         NaN      -3.0   73239.0
# 100283                                         NaN       3.0   73240.0
#
# [99793 rows x 21 columns]

# %% [markdown]
# ## **removing NULL column that is "Estimated Onset Dat**e"

# %%
pat_data.drop('Estimated Onset Date',axis=1,inplace=True)

# %%
pat_data
# Out:
#         Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0                  1.0             KL-TS-P1     30/01/2020          20      F
# 1                  2.0             KL-AL-P1     02/02/2020         NaN    NaN
# 2                  3.0             KL-KS-P1     03/02/2020         NaN    NaN
# 3                  4.0                DL-P1     02/03/2020          45      M
# 4                  5.0                TS-P1     02/03/2020          24      M
# ...                ...                  ...            ...         ...    ...
# 100279        102515.0                  NaN     19/06/2020         NaN    NaN
# 100280        102516.0                  NaN     19/06/2020         NaN    NaN
# 100281        102517.0                  NaN     19/06/2020         NaN    NaN
# 100282        102609.0                  NaN     19/06/2020         NaN    NaN
# 100283        102610.0                  NaN     19/06/2020         NaN    NaN
#
#                    Detected City Detected District     Detected State  \
# 0                       Thrissur          Thrissur             Kerala
# 1                      Alappuzha         Alappuzha             Kerala
# 2                      Kasaragod         Kasaragod             Kerala
# 3       East Delhi (Mayur Vihar)        East Delhi              Delhi
# 4                      Hyderabad         Hyderabad          Telangana
# ...                          ...               ...                ...
# 100279                       NaN           Pulwama  Jammu and Kashmir
# 100280                       NaN             Reasi  Jammu and Kashmir
# 100281                       NaN          Kishtwar  Jammu and Kashmir
# 100282                       NaN       East Sikkim             Sikkim
# 100283                       NaN      South Sikkim             Sikkim
#
#        State code Current Status  \
# 0              KL      Recovered
# 1              KL      Recovered
# 2              KL      Recovered
# 3              DL      Recovered
# 4              TG      Recovered
# ...           ...            ...
# 100279         JK   Hospitalized
# 100280         JK      Recovered
# 100281         JK      Recovered
# 100282         SK      Recovered
# 100283         SK      Recovered
#
#                                                     Notes Nationality  \
# 0                                    Travelled from Wuhan       India
# 1                                    Travelled from Wuhan       India
# 2                                    Travelled from Wuhan       India
# 3                           Travelled from Austria, Italy       India
# 4       Travelled from Dubai to Bangalore on 20th Feb,...       India
# ...                                                   ...         ...
# 100279                                                NaN         NaN
# 100280                                                NaN         NaN
# 100281                                                NaN         NaN
# 100282     Entry was done on 13 Jun but re-concilled now          NaN
# 100283     Entry was done on 13 Jun but re-concilled now          NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 100279                  NaN                NaN
# 100280                  NaN                NaN
# 100281                  NaN                NaN
# 100282                  NaN                NaN
# 100283                  NaN                NaN
#
#                                                  Source_1  \
# 0       https://twitter.com/vijayanpinarayi/status/122...
# 1       https://www.indiatoday.in/india/story/kerala-r...
# 2       https://www.indiatoday.in/india/story/kerala-n...
# 3       https://www.indiatoday.in/india/story/not-a-ja...
# 4       https://www.deccanherald.com/national/south/qu...
# ...                                                   ...
# 100279  https://twitter.com/diprjk/status/127434387638...
# 100280  https://twitter.com/diprjk/status/127434387638...
# 100281  https://twitter.com/diprjk/status/127434387638...
# 100282  https://www.eastmojo.com/coronavirus-updates/2...
# 100283  https://www.eastmojo.com/coronavirus-updates/2...
#
#                                                  Source_2  \
# 0       https://weather.com/en-IN/india/news/news/2020...
# 1       https://weather.com/en-IN/india/news/news/2020...
# 2       https://twitter.com/ANI/status/122422148580539...
# 3       https://economictimes.indiatimes.com/news/poli...
# 4       https://www.indiatoday.in/india/story/coronavi...
# ...                                                   ...
# 100279                                                NaN
# 100280                                                NaN
# 100281                                                NaN
# 100282                                                NaN
# 100283                                                NaN
#
#                                                  Source_3  \
# 0                                                     NaN
# 1                                                     NaN
# 2       https://weather.com/en-IN/india/news/news/2020...
# 3                                                     NaN
# 4       https://www.thehindu.com/news/national/coronav...
# ...                                                   ...
# 100279                                                NaN
# 100280                                                NaN
# 100281                                                NaN
# 100282                                                NaN
# 100283                                                NaN
#
#                                       Backup Notes  Num Cases  Entry_ID
# 0                               Student from Wuhan        1.0       NaN
# 1                               Student from Wuhan        1.0       NaN
# 2                               Student from Wuhan        1.0       NaN
# 3              Travel history to Italy and Austria        1.0       NaN
# 4       Travel history to Dubai, Singapore contact        1.0       NaN
# ...                                            ...        ...       ...
# 100279                                         NaN        1.0   73145.0
# 100280                                         NaN        2.0   73146.0
# 100281                                         NaN       -2.0   73147.0
# 100282                                         NaN       -3.0   73239.0
# 100283                                         NaN        3.0   73240.0
#
# [99793 rows x 20 columns]

# %% [markdown]
# # **since we won't be needing Detected City,Detected District ,Gender and sources_1,sources_2,sources_3 since it's not needed for this project so we are droping those columns**

# %%
pat_data.drop(columns=['Detected City','Detected District','Gender','Source_1','Source_2','Source_3'],inplace=True)

# %%
pat_data
# Out:
#         Patient Number State Patient Number Date Announced Age Bracket  \
# 0                  1.0             KL-TS-P1     30/01/2020          20
# 1                  2.0             KL-AL-P1     02/02/2020         NaN
# 2                  3.0             KL-KS-P1     03/02/2020         NaN
# 3                  4.0                DL-P1     02/03/2020          45
# 4                  5.0                TS-P1     02/03/2020          24
# ...                ...                  ...            ...         ...
# 100279        102515.0                  NaN     19/06/2020         NaN
# 100280        102516.0                  NaN     19/06/2020         NaN
# 100281        102517.0                  NaN     19/06/2020         NaN
# 100282        102609.0                  NaN     19/06/2020         NaN
# 100283        102610.0                  NaN     19/06/2020         NaN
#
#            Detected State State code Current Status  \
# 0                  Kerala         KL      Recovered
# 1                  Kerala         KL      Recovered
# 2                  Kerala         KL      Recovered
# 3                   Delhi         DL      Recovered
# 4               Telangana         TG      Recovered
# ...                   ...        ...            ...
# 100279  Jammu and Kashmir         JK   Hospitalized
# 100280  Jammu and Kashmir         JK      Recovered
# 100281  Jammu and Kashmir         JK      Recovered
# 100282             Sikkim         SK      Recovered
# 100283             Sikkim         SK      Recovered
#
#                                                     Notes Nationality  \
# 0                                    Travelled from Wuhan       India
# 1                                    Travelled from Wuhan       India
# 2                                    Travelled from Wuhan       India
# 3                           Travelled from Austria, Italy       India
# 4       Travelled from Dubai to Bangalore on 20th Feb,...       India
# ...                                                   ...         ...
# 100279                                                NaN         NaN
# 100280                                                NaN         NaN
# 100281                                                NaN         NaN
# 100282     Entry was done on 13 Jun but re-concilled now          NaN
# 100283     Entry was done on 13 Jun but re-concilled now          NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 100279                  NaN                NaN
# 100280                  NaN                NaN
# 100281                  NaN                NaN
# 100282                  NaN                NaN
# 100283                  NaN                NaN
#
#                                       Backup Notes  Num Cases  Entry_ID
# 0                               Student from Wuhan        1.0       NaN
# 1                               Student from Wuhan        1.0       NaN
# 2                               Student from Wuhan        1.0       NaN
# 3              Travel history to Italy and Austria        1.0       NaN
# 4       Travel history to Dubai, Singapore contact        1.0       NaN
# ...                                            ...        ...       ...
# 100279                                         NaN        1.0   73145.0
# 100280                                         NaN        2.0   73146.0
# 100281                                         NaN       -2.0   73147.0
# 100282                                         NaN       -3.0   73239.0
# 100283                                         NaN        3.0   73240.0
#
# [99793 rows x 14 columns]

# %% [markdown]
# ### **dropping any row whose all values/cells are NA**

# %%
pat_data.dropna(how='all', axis=0, inplace=True)

# %%
pat_data
# Out:
#         Patient Number State Patient Number Date Announced Age Bracket  \
# 0                  1.0             KL-TS-P1     30/01/2020          20
# 1                  2.0             KL-AL-P1     02/02/2020         NaN
# 2                  3.0             KL-KS-P1     03/02/2020         NaN
# 3                  4.0                DL-P1     02/03/2020          45
# 4                  5.0                TS-P1     02/03/2020          24
# ...                ...                  ...            ...         ...
# 100279        102515.0                  NaN     19/06/2020         NaN
# 100280        102516.0                  NaN     19/06/2020         NaN
# 100281        102517.0                  NaN     19/06/2020         NaN
# 100282        102609.0                  NaN     19/06/2020         NaN
# 100283        102610.0                  NaN     19/06/2020         NaN
#
#            Detected State State code Current Status  \
# 0                  Kerala         KL      Recovered
# 1                  Kerala         KL      Recovered
# 2                  Kerala         KL      Recovered
# 3                   Delhi         DL      Recovered
# 4               Telangana         TG      Recovered
# ...                   ...        ...            ...
# 100279  Jammu and Kashmir         JK   Hospitalized
# 100280  Jammu and Kashmir         JK      Recovered
# 100281  Jammu and Kashmir         JK      Recovered
# 100282             Sikkim         SK      Recovered
# 100283             Sikkim         SK      Recovered
#
#                                                     Notes Nationality  \
# 0                                    Travelled from Wuhan       India
# 1                                    Travelled from Wuhan       India
# 2                                    Travelled from Wuhan       India
# 3                           Travelled from Austria, Italy       India
# 4       Travelled from Dubai to Bangalore on 20th Feb,...       India
# ...                                                   ...         ...
# 100279                                                NaN         NaN
# 100280                                                NaN         NaN
# 100281                                                NaN         NaN
# 100282     Entry was done on 13 Jun but re-concilled now          NaN
# 100283     Entry was done on 13 Jun but re-concilled now          NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 100279                  NaN                NaN
# 100280                  NaN                NaN
# 100281                  NaN                NaN
# 100282                  NaN                NaN
# 100283                  NaN                NaN
#
#                                       Backup Notes  Num Cases  Entry_ID
# 0                               Student from Wuhan        1.0       NaN
# 1                               Student from Wuhan        1.0       NaN
# 2                               Student from Wuhan        1.0       NaN
# 3              Travel history to Italy and Austria        1.0       NaN
# 4       Travel history to Dubai, Singapore contact        1.0       NaN
# ...                                            ...        ...       ...
# 100279                                         NaN        1.0   73145.0
# 100280                                         NaN        2.0   73146.0
# 100281                                         NaN       -2.0   73147.0
# 100282                                         NaN       -3.0   73239.0
# 100283                                         NaN        3.0   73240.0
#
# [99793 rows x 14 columns]

# %% [markdown]
# # we don't need "State Patient Number" as its not contributing to any of our analysis questions

# %%
pat_data.drop('State Patient Number',axis =1,inplace=True)

# %%
pat_data
# Out:
#         Patient Number Date Announced Age Bracket     Detected State  \
# 0                  1.0     30/01/2020          20             Kerala
# 1                  2.0     02/02/2020         NaN             Kerala
# 2                  3.0     03/02/2020         NaN             Kerala
# 3                  4.0     02/03/2020          45              Delhi
# 4                  5.0     02/03/2020          24          Telangana
# ...                ...            ...         ...                ...
# 100279        102515.0     19/06/2020         NaN  Jammu and Kashmir
# 100280        102516.0     19/06/2020         NaN  Jammu and Kashmir
# 100281        102517.0     19/06/2020         NaN  Jammu and Kashmir
# 100282        102609.0     19/06/2020         NaN             Sikkim
# 100283        102610.0     19/06/2020         NaN             Sikkim
#
#        State code Current Status  \
# 0              KL      Recovered
# 1              KL      Recovered
# 2              KL      Recovered
# 3              DL      Recovered
# 4              TG      Recovered
# ...           ...            ...
# 100279         JK   Hospitalized
# 100280         JK      Recovered
# 100281         JK      Recovered
# 100282         SK      Recovered
# 100283         SK      Recovered
#
#                                                     Notes Nationality  \
# 0                                    Travelled from Wuhan       India
# 1                                    Travelled from Wuhan       India
# 2                                    Travelled from Wuhan       India
# 3                           Travelled from Austria, Italy       India
# 4       Travelled from Dubai to Bangalore on 20th Feb,...       India
# ...                                                   ...         ...
# 100279                                                NaN         NaN
# 100280                                                NaN         NaN
# 100281                                                NaN         NaN
# 100282     Entry was done on 13 Jun but re-concilled now          NaN
# 100283     Entry was done on 13 Jun but re-concilled now          NaN
#
#        Type of transmission Status Change Date  \
# 0                  Imported         14/02/2020
# 1                  Imported         14/02/2020
# 2                  Imported         14/02/2020
# 3                  Imported         15/03/2020
# 4                  Imported         02/03/2020
# ...                     ...                ...
# 100279                  NaN                NaN
# 100280                  NaN                NaN
# 100281                  NaN                NaN
# 100282                  NaN                NaN
# 100283                  NaN                NaN
#
#                                       Backup Notes  Num Cases  Entry_ID
# 0                               Student from Wuhan        1.0       NaN
# 1                               Student from Wuhan        1.0       NaN
# 2                               Student from Wuhan        1.0       NaN
# 3              Travel history to Italy and Austria        1.0       NaN
# 4       Travel history to Dubai, Singapore contact        1.0       NaN
# ...                                            ...        ...       ...
# 100279                                         NaN        1.0   73145.0
# 100280                                         NaN        2.0   73146.0
# 100281                                         NaN       -2.0   73147.0
# 100282                                         NaN       -3.0   73239.0
# 100283                                         NaN        3.0   73240.0
#
# [99793 rows x 13 columns]

# %% [markdown]
# ## **Drop Any Row which has even 1 cell =NA**

# %%
pat_data.dropna(subset='Nationality',axis=0,inplace=True)

# %%
pat_data
# Out:
#        Patient Number Date Announced Age Bracket Detected State State code  \
# 0                 1.0     30/01/2020          20         Kerala         KL
# 1                 2.0     02/02/2020         NaN         Kerala         KL
# 2                 3.0     03/02/2020         NaN         Kerala         KL
# 3                 4.0     02/03/2020          45          Delhi         DL
# 4                 5.0     02/03/2020          24      Telangana         TG
# ...               ...            ...         ...            ...        ...
# 11589         11590.0     15/04/2020           1      Karnataka         KA
# 11590         11591.0     15/04/2020          38      Karnataka         KA
# 11591         11592.0     15/04/2020          25      Karnataka         KA
# 11592         11593.0     15/04/2020          32      Karnataka         KA
# 11680         11681.0     15/04/2020          50    Maharashtra         MH
#
#       Current Status                                              Notes  \
# 0          Recovered                               Travelled from Wuhan
# 1          Recovered                               Travelled from Wuhan
# 2          Recovered                               Travelled from Wuhan
# 3          Recovered                      Travelled from Austria, Italy
# 4          Recovered  Travelled from Dubai to Bangalore on 20th Feb,...
# ...              ...                                                ...
# 11589   Hospitalized                             Influenza like illness
# 11590   Hospitalized                                 Contact of KA-P221
# 11591   Hospitalized                                 Contact of KA-P221
# 11592   Hospitalized                                 Contact of KA-P252
# 11680       Deceased   Admitted to Sassoon Hospital on 15th April, 2020
#
#       Nationality Type of transmission Status Change Date  \
# 0           India             Imported         14/02/2020
# 1           India             Imported         14/02/2020
# 2           India             Imported         14/02/2020
# 3           India             Imported         15/03/2020
# 4           India             Imported         02/03/2020
# ...           ...                  ...                ...
# 11589       India                Local         15/04/2020
# 11590       India                Local         15/04/2020
# 11591       India                Local         15/04/2020
# 11592       India                Local         15/04/2020
# 11680       India                Local         17/04/2020
#
#                                      Backup Notes  Num Cases  Entry_ID
# 0                              Student from Wuhan        1.0       NaN
# 1                              Student from Wuhan        1.0       NaN
# 2                              Student from Wuhan        1.0       NaN
# 3             Travel history to Italy and Austria        1.0       NaN
# 4      Travel history to Dubai, Singapore contact        1.0       NaN
# ...                                           ...        ...       ...
# 11589                                         NaN        1.0       NaN
# 11590                                         NaN        1.0       NaN
# 11591                                         NaN        1.0       NaN
# 11592                                         NaN        1.0       NaN
# 11680                                         NaN        1.0       NaN
#
# [1554 rows x 13 columns]
