# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavita2501/DAB-103/blob/main/Group_Project_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Project Directory path 
project_dir = 'drive/MyDrive/PYTHON-DEMO/PROJECT/'

# %%
import pandas as pd

# %%
state_level_daily = pd.read_csv(project_dir+ 'state_level_daily.csv')
state_level_daily
# Out:
#       Unnamed: 0       Date State  Confirmed  Deceased  Recovered  \
# 0              0  01-Apr-20    AN          0         0          0
# 1              1  01-Apr-20    AP         67         0          1
# 2              2  01-Apr-20    AR          0         0          0
# 3              3  01-Apr-20    AS         15         0          0
# 4              4  01-Apr-20    BR          3         0          0
# ...          ...        ...   ...        ...       ...        ...
# 5689        5689  31-May-20    TT       8789       222       4928
# 5690        5690  31-May-20    UN        448         0          0
# 5691        5691  31-May-20    UP        374         4        192
# 5692        5692  31-May-20    UT        158         0          0
# 5693        5693  31-May-20    WB        371         8        187
#
#                        State_Name
# 0     Andaman and Nicobar Islands
# 1                  Andhra Pradesh
# 2               Arunachal Pradesh
# ...

# %%
patients_data = pd.read_csv(project_dir+ 'patients_data.csv')
patients_data
# Out:
# <ipython-input-17-d9d42643832a>:1: DtypeWarning: Columns (4,12,13,14,15,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   patients_data = pd.read_csv(project_dir+ 'patients_data.csv')
#         Patient Number State Patient Number Date Announced  \
# 0                  1.0             KL-TS-P1     30/01/2020
# 1                  2.0             KL-AL-P1     02/02/2020
# 2                  3.0             KL-KS-P1     03/02/2020
# 3                  4.0                DL-P1     02/03/2020
# 4                  5.0                TS-P1     02/03/2020
# ...                ...                  ...            ...
# 247231             NaN                  NaN     06/08/2020
# 247232             NaN                  NaN     06/08/2020
# 247233             NaN                  NaN     06/08/2020
# 247234             NaN                  NaN     06/08/2020
# 247235             NaN                  NaN            NaN
#
# ...

# %%
nation_level_daily = pd.read_csv(project_dir+ 'nation_level_daily.csv')

nation_level_daily
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0     30 January                 1                1                0
# 1     31 January                 0                1                0
# 2    01 February                 0                1                0
# 3    02 February                 1                2                0
# 4    03 February                 1                3                0
# ..            ...              ...              ...              ...
# 185    02 August             52672          1804857            40355
# 186    03 August             50488          1855345            43070
# 187    04 August             51282          1906627            51220
# 188    05 August             56626          1963253            45583
# 189    06 August             62170          2025423            50141
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# ...
